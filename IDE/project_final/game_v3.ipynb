# %% [markdown]
# # Игра угадай число

# %%
from game_v3 import game_core_v3, score_game

# %% [markdown]
# ## Угадываем рандомно

# %%
score_game(game_core_v3)
# Out:
# Ваш алгоритм угадывает число в среднем за:16 попыток
# 16
